# %%
import re
import json

import xml.etree.ElementTree as ET
import pandas as pd

# %%
causal_regex = re.compile(
    r"(?i)"
    r"(?:"
    r"why\b"                                    # "Why does prolonged stress contribute to heart disease?"
    r"|causes?\b"                               # "What causes insulin resistance in type 2 diabetes?"
    r"|how\s+(?:come|did)\b"                    # "How did genetic mutations lead to this rare disorder?"
    r"|effects?\b|affects?\b"                   # "How does hypertension affect kidney function?"
    r"|leads?\s+to\b"                           # "What does chronic inflammation lead to in autoimmune diseases?"
    r"|what\s+(?:will|might)?\s*happen(?:s)?\b" # "What happens if a stroke is left untreated?"
    r"|what\s+(?:to\s+do|should\s+be\s+done)\b" # "What should be done for a patient with sepsis?"
    r"|impacts?\b"                              # "What is the impact of obesity on cardiovascular health?"
    r"|consequences?\b"                         # "What are the consequences of delayed cancer diagnosis?"
    r"|outcomes?\b"                             # "What are the outcomes of untreated gestational diabetes?"
    r"|results?\s+(?:from|in)\b"                # "What results from prolonged high cholesterol levels?"
    r"|influence(?:s)?\b"                       # "How does smoking influence the progression of COPD?"
    r"|implications?\b"                         # "What are the implications of genetic predisposition to Alzheimer's?"
    r"|associated\s+with\b"                     # "What complications are associated with uncontrolled diabetes?"
    r"|linked\s+to\b"                           # "What risk factors are linked to cardiovascular disease?"
    r"|related\s+to\b"                          # "What symptoms are related to liver failure?"
    r"|if\s+.+then\b"                           # "If the patient has high BP, then what will occur?"
    r"|when\s+.+happens\b"                      # "When fever occurs, what is the likely outcome?"
    r"|could\s+.+cause\b"                       # "Could anemia cause heart palpitations?"
    r"|what\s+is\s+the\s+reason\b"              # "What is the reason behind sudden weight loss?"
    r"|reason\s+for\b"                          # "What is the reason for high creatinine levels?"
    r")",
    re.IGNORECASE
)

# %%
def contains_keyword(message, keywords):
    pattern = re.compile(r'\b(?:' + '|'.join(re.escape(keyword) for keyword in keywords) + r')\b', re.IGNORECASE)
    return bool(pattern.search(message))

def contains_causal_relation(message):
    return bool(causal_regex.search(message))


def format_options(option_dict):
    option_str = str(option_dict)
    # Regex pattern to match 'correct answer' key-value pair
    option_str = re.sub(r"'correct answer': '.*?'", "", option_str)
    # Clean up extra commas left after removing the key-value pair
    option_str = re.sub(r",\s*,", ",", option_str)
    option_str = re.sub(r",\s*}$", "}", option_str)
    return (option_str)

# %%
idf = pd.read_csv('data/reasoning_FCT_reasoning_FCT.csv',)
dataset = idf.copy()
print(len(dataset))
# Out:
# 18866

# %%
data_causal = []
data_generic = []
# Iterate through each question in the XML
for idx, row in dataset.iterrows():
    qid = idx
    question = row['question']
    options = row['options']
    formatted_options = format_options(options)
    print(formatted_options)
    if contains_causal_relation(question):
        data_causal.append({'id': qid, 'question': question, 'options': formatted_options, 'correct_answer': row['correct_answer'], 'correct_index' :  row['correct_index']})
    else:
        data_generic.append({'id': qid, 'question': question, 'options': formatted_options, 'correct_answer': row['correct_answer'], 'correct_index' :  row['correct_index']})
# Create the DataFrame
df_causal = pd.DataFrame(data_causal)
df_gen = pd.DataFrame(data_generic)
# Out:
# {'0': 'They are anilides with propyl group in ortho.', '1': 'They are benzamides with methoxy group in ortho.', '2': 'They are benzenesulfonamides with a methyl group in ortho.', '3': 'They are ortho-halogenated derivatives of phenothiazine.'}
# {'0': 'Young children (Early Childhood Education and first courses of Primary Education).', '1': 'Older children (last courses of Primary Education).', '2': 'Preadolescents (first courses of Secondary Education).', '3': 'Adolescents (last years of Secondary Education and Bachillerato).'}
# {'0': '＜130/80 mmHg', '1': '150-160/90-95 mmHg', '2': '＜140/90 mmHg', '3': '＜140/85 mmHg'}
# {'0': 'Cause less gingival shrinking', '1': 'Cause Less scars', '2': 'Less intra-operative bleeding', '3': 'None of the above'}
# {'0': 'Bicarbonate', '1': 'Albumin', '2': 'Phosphate', '3': 'Ammonia'}
# {'0': 'Uterine prolapsed', '1': 'Stress urinary incontinence', '2': 'Vesicovaginal fistula', '3': 'Uteric fistula'}
# {'0': 'Hydrolysis of glucocerebroside', '1': 'DNA interstrand crosslink repair', '2': 'Maturation of erythroid progenitor cells', '3': 'Ras signal transduction pathway'}
# {'0': 'Prophylactic antibiotic therapy to prevent future UTIs', '1': 'Voiding cystourethrogram', '2': 'Renal bladder ultrasound', '3': 'Repeat urine culture'}
# {'0': 'Thoracic', '1': 'Abdomen', '2': 'Cervical', '3': 'Any of the above'}
# {'0': 'Adjuvant', '1': 'Preservative', '2': 'Stabilizar', '3': 'Antiinfective'}
# {'0': 'Distal renal tubular acidosis', '1': 'Hypophosphatemic rickets.', '2': 'Vitamin D dependent rickets', '3': 'Proximal renal tubular acidosis'}
# {'0': 'Parathyroid', '1': 'Adrenal', '2': 'Thyroid', '3': 'Pituitary'}
# {'0': 'Switch blood pressure medication to losartan', '1': 'Switch blood pressure medication to hydrochlorothiazide', '2': 'Azithromycin', '3': 'Loratadine'}
# {'0': 'Ankylosing spondylitis.', '1': 'Ankylosing vertebral hyperostosis.', '2': "Paget's disease.", '3': 'Psoriatic arthropathy'}
# {'0': 'Amino acids', '1': 'Carbonic acids', '2': 'Phosphates', '3': 'None'}
# {'0': 'Ibuprofen', '1': 'Tetracycline', '2': 'Amoxicilin', '3': 'Gentamicin'}
# {'0': 'Decidua basalis layer', '1': 'Decidua capsularis layer', '2': 'Decidua parietalis', '3': 'Decidua spongiosa'}
# {'0': 'The consumption of harmful risk of alcohol.', '1': 'The consumption of tobacco.', '2': 'Sexual health', '3': 'Emotional well-being'}
# {'0': 'Vascularization increases or the epithelial keratinization is reduced', '1': 'Vascularization increases or the epithelial keratinization is increased', '2': 'Vascularization decreases or the epithelial keratinization is reduced', '3': 'Vascularization decreases or the epithelial keratinization is increased'}
# {'0': 'The most likely pathological picture is organized pneumonia.', '1': 'An amiodarone pneumonitis seems unlikely given that the patient has taken the drug for 2 years.', '2': 'The lymphocyte ratio of bronchoalveolar lavage suggests a picture of sarcoidosis.', '3': 'The picture suggests a pneumonia of fibrotic type.'}
# {'0': 'Pancreatic carcinoma', '1': 'Thyroid carcinoma', '2': 'Endometrial carcinoma', '3': 'None'}
# {'0': 'Protease release', '1': 'Phagocytosis', '2': 'Surfactant secretion', '3': 'Recruitment of neutrophils'}
# {'0': 'Pyruvate.', '1': 'Glucose-6-phosphate.', '2': 'Acetyl-CoA.', '3': 'Fosfoenolpiruvato.'}
# {'0': "'72 hour' fast test", '1': 'Plasma Glucose levels < 3 mmol/l', '2': 'Plasma Insulin levels > 6uU/ml', '3': 'C- peptide levels < 50 p mol/e'}
# {'0': 'Dubin-Johnson syndrome', '1': 'Gilbert syndrome', '2': 'Breast feeding jaundice', '3': 'Erythroblastosis fetalis'}
# {'0': "Wernicke's hemianopic pupil", '1': 'Amauratic pupil', '2': 'Amauratic pupil', '3': 'None'}
# {'0': 'Inhaled beclomethasone', '1': 'Inhaled ipratropium bromide', '2': 'Nebulized theophylline', '3': 'Inhaled salmeterol'}
# {'0': 'Eosinophils', '1': 'Mesenchymal cells', '2': 'Platelets', '3': 'Thymic epithelial cells'}
# {'0': 'Tm value and GC content of DNA related', '1': 'Tm values \u200b\u200band ionic concentration was about', '2': 'The pH of the solution and the Tm value independent', '3': 'And the Tm value of the length of the relevant DNA'}
# {'0': 'Can increase insulin secretion of pancreatic β cells', '1': 'Can increase insulin secretion by inhibition of ATP-sensitive K + channel of', '2': 'To a multi-peptide (Polypeptide)', '3': 'Enhance muscle and fat cells to absorb glucose'}
# {'0': 'Femoral nerve', '1': 'Tibial nerve', '2': 'Common peroneal nerve', '3': 'Sciatic nerve'}
# {'0': 'alprazolam', '1': 'chlordiazepoxide', '2': 'flurazepam', '3': 'zaleplon'}
# {'0': 'Hephaestin', '1': 'Ferropoin', '2': 'Divalent metal ion transpoer', '3': 'Transferrin'}
# {'0': 'Valine', '1': 'Aspaic acid', '2': 'Arginine', '3': 'Isoleucine'}
# {'0': 'Kayser-Fleischer ring', '1': 'Latte spots', '2': 'Cherry red spots', '3': 'Lisch nodules'}
# {'0': 'Reason scales', '1': 'Rated classification systems', '2': 'Interval systems', '3': 'Ordinal scales.'}
# {'0': 'Ag', '1': 'Zn', '2': 'Platinum', '3': 'Indium'}
# {'0': 'Dapsone plus steroids', '1': 'Stop smoking and screen for cancer', '2': 'Vitamin supplements', '3': 'Antifungals for oral candidiasis'}
# {'0': 'Bicoronal craniosynostosis', '1': 'Midface hypoplasia', '2': 'Mandibular hypoplasia', '3': 'Complex syndactyly'}
# {'0': 'Alveolar crest group', '1': 'Trans-septal group', '2': 'Oblique group', '3': 'Apical group'}
# {'0': '"I have to eat more fruit and vegetables, although I do not like anything!"', '1': '"I do not smell chocolate!"', '2': '"I can not afford the cured cheese because I have very high phosphorus."', '3': '"I must limit the amount of liquids I drink."'}
# {'0': 'A strategy that has several elements comprising in an integrated manner several programs aimed at populations for general health.', '1': 'Set of instruments and decisions of a certain society that assigns social functions and at the same time resources to reach a health goal of a population.', '2': "Global political and social process aimed at increasing people's control over the determinants of health.", '3': 'Measures designed not only to prevent the onset of the disease, such as the reduction of risk factors, but also to stop its progress and mitigate its consequences once established.'}
# {'0': "It should start with activities that have not been part of the person's repertoire.", '1': "The patient's activities should be structured according to their mood.", '2': 'Activities that involve natural reinforcement should be prioritized.', '3': 'The change is more difficult if you start little by little.', 'correct answer': "It should start with activities that have not been part of the person's repertoire."}
# {'0': 'There may be left to right shunt lesions, resulting in heart failure', '1': 'There may be a right-to-left shunt lesions, resulting in hypoxia', '2': 'Upper respiratory tract infection may be', '3': 'Pulmonary stenosis may be the cause of right heart failure'}
# {'0': 'Insulin stimulates the HMG-CoA reductase', '1': 'High intracellular concentration of cholesterol stimulates lipid cholesterol (cholesterol ester) formed', '2': 'Intake of dietary cholesterol does not affect the synthesis of cholesterol in the liver cells', '3': 'Some intermediate metabolite inhibits cholesterol HMG-CoA reductase'}
# {'0': 'Center Weighted slow stroke', '1': 'Withdrawal symptoms do not appear in Disables five days after', '2': 'Convulsions hair as more severe the withdrawal symptoms', '3': 'Withdrawal symptoms as not producing ⽣ delirium'}
# {'0': 'vWD type 1', '1': 'vWD type 2A', '2': 'vWD type 2N', '3': 'vWD type 3'}
# {'0': 'Secondary waves occur.', '1': 'There is a rapid rise in the wave which flattens (Plateau).', '2': 'All cases occur in a single incubation period of the disease.', '3': 'It is propagative.'}
# {'0': 'Anterior interosseous', '1': 'Posterior interosseous', '2': 'Median', '3': 'Ulnar'}
# {'0': 'Lateral lemniscus', '1': 'Superior olivary complex', '2': 'Cochlear nerve', '3': 'Cochlear nucleus'}
# {'0': 'Increasing the width of attached gingiva', '1': 'Recession coverage', '2': 'Curettage', '3': 'Vestibular deepening'}
# {'0': 'Maxillary 1st premolar', '1': 'Mandibular lateral incisor', '2': 'Maxillary lateral incisor', '3': 'Mandibular 1st premolar'}
# {'0': 'After professional judgment does not require added albumin, after more communication with the patient declined the requirements of the patient, do not give albumin supplements after surgery', '1': 'Patients agreed to add albumin, and to pay for health care', '2': 'Even if the judge added albumin is not the appropriate medical treatment, but the patient requires, and it would not hurt to add', '3': 'Added albumin is a medical professional judgment to determine by a physician, do not need to communicate with patients'}
# {'0': '1000 gm', '1': '1300 gm', '2': '1600 gm', '3': '2000 gm'}
# {'0': 'Precontemplation, preparation, planning, action, maintenance and relapses.', '1': 'Contemplation preparation, planning, action, maintenance and relapses.', '2': 'Preparation, contemplation, preaction, action and evaluation.', '3': 'Precontemplation, contemplation, preparation, action, maintenance and relapses.'}
# {'0': 'Try to change the emotional reactions of the patient in the short term (sadness, discouragement, disinterest, etc.)', '1': "It completely abandons the goal of changing the patient's emotions.", '2': 'Pretend that the emotions change to produce a change in behavior.', '3': 'It is necessary in the short term to accept the emotions of the patient.'}
# {'0': 'HLA B27', '1': 'B/l sactoilitis', '2': 'Lumbar movement', '3': 'ESR'}
# {'0': 'Hepatitis A infection', '1': 'Hepatitis B infection', '2': 'Hepatitis C infection', '3': 'Hepatitis D infection'}
# {'0': 'The convex buccal surface of the tooth.', '1': 'In between the embrasures.', '2': 'The convex lingual surface of the tooth.', '3': 'None.'}
# {'0': 'Middle concha', '1': 'Inferior concha', '2': 'Middle meatus', '3': 'Inferior meatus'}
# {'0': '①③', '1': '②③', '2': '②④', '3': '①②'}
# {'0': 'Pa02', '1': 'PaCO2', '2': 'HCO3', '3': 'None of the above'}
# {'0': 'Syphilis', '1': 'Head injury', '2': 'Endocarditis', '3': 'Atherosclerosis'}
# {'0': 'one.', '1': 'two.', '2': 'Four.', '3': '8'}
# {'0': 'Hypoxia', '1': 'Hypercapnoea', '2': 'Hypocapnoea', '3': 'Dissolved H+ ions in blood'}
# {'0': 'Vaselines, oils, waxes and silicones.', '1': 'Vaseline, lanolin and fatty alcohols.', '2': 'Macrogoles (PEG) liquids and solids.', '3': 'White ointment: white wax (5%) and filamentous vaseline (95%).'}
# {'0': 'brain', '1': 'heart', '2': 'liver', '3': 'kidney'}
# {'0': 'C5a.', '1': 'C1 inhibitor.', '2': 'C3b.', '3': 'Factor B.'}
# {'0': 'Be on antibiotic treatment at that time.', '1': 'Be convalescing from a mild illness', '2': 'Corticoterapia of short duration.', '3': 'Decompensated cardiopathies.'}
# {'0': 'Squatting', '1': 'Standing up from a sitting position', '2': 'Diuretics', '3': 'Volume depletion'}
# {'0': 'Services that include technicians and professionals, citizenship and administration.', '1': 'Professionals of Social Work, Medicine and Nursing.', '2': 'Politicians, health personnel and education personnel.', '3': 'Health personnel, personnel of the educational field and personnel of the social sector.'}
# {'0': 'Sympathetic', '1': 'Parasympathetic', '2': 'Wheal and flare', '3': 'Warm climate'}
# {'0': 'CH group 0 positive and PFC AB positive.', '1': 'CH of group 0 negative and PFC 0 negative.', '2': 'CH of group 0 negative and PFC AB negative.', '3': 'CH group 0 positive and PFC 0 positive.'}
# {'0': 'Epigenetics', '1': 'Translocation', '2': 'Inversion', '3': 'Transduction'}
# {'0': 'Viral entry into host cell', '1': 'Viral polypeptide cleavage', '2': 'Viral budding from host cells', '3': 'Reverse transcription of viral RNA'}
# {'0': 'Plan normal vaginal delivery at term', '1': 'Determine hepatitis B e antigen serum level', '2': 'Administer hepatitis B vaccine to mother', '3': 'Perform liver biopsy of mother'}
# {'0': 'Before the ion exchange separation column.', '1': 'After the ion exchange separation column.', '2': 'After the detector.', '3': 'Before the injection valve.'}
# {'0': 'Nocardia brasiliensis', '1': 'Streptococcus pyogenes.', '2': 'Staphylococcus epidermidis.', '3': 'Enterococcus faecium.'}
# {'0': 'The predominant symptomatology in paracetamol poisonings is hepatotoxicity.', '1': 'Gastric lavage is not indicated as a therapeutic measure in the management of acute paracetamol poisoning.', '2': 'The cornerstone in the treatment of paracetamol poisoning is its specific antidote, N-acetylcysteine.', '3': 'Gastrointestinal decontamination by the administration of activated charcoal is indicated if less than 4 hours have elapsed from the intake of paracetamol at a toxic or unknown dose.'}
# {'0': 'Prediabetics', '1': 'Prehypertensive', '2': 'X chromosome mutation', '3': 'More chances of syncope during dental extractions'}
# {'0': '0.5 hours', '1': '1 hour', '2': '1.5 hours', '3': '2 hours'}
# {'0': '1 mm', '1': '3 mm', '2': '5 mm', '3': '7 mm'}
# {'0': 'CT scan', '1': 'Surgery', '2': 'D-dimer', '3': 'Intravenous ultrasound'}
# {'0': 'Polyacrylic acid is liquid', '1': 'Chemical bond to tooth structure', '2': 'Chelation', '3': 'Substitution of eugenol by EBA to increase strength of cement'}
# {'0': 'Mefloquine by mouth', '1': 'Intravenous artesunate.', '2': 'Doxycycline orally.', '3': 'Quinine sulfate orally.'}
# {'0': 'Lymphomas are the most common small intestinal tumors', '1': 'Carcinoids are more common in the duodenum and jejunum', '2': 'Adenomatous polyps are more common in the terminal ileum', '3': 'Risk of developing small bowel tumor correlates positively with colorectal cancer'}
# {'0': 'Disability limitation', '1': 'Rehabilitation', '2': 'Early diagnosis and prompt treatment', '3': 'Specific protection'}
# {'0': '8 molecules of acetyl-CoA and a monocarbonate fragment.', '1': '7 molecules of acetyl-CoA and 1 molecule of propionyl-CoA.', '2': '7 molecules of acetyl-CoA and 1 molecule of malonyl-CoA.', '3': '6 molecules of acetyl-CoA and 1 molecule of succinyl-CoA.'}
# {'0': 'Hypomagnesemia', '1': 'Histamine release', '2': 'Leukopenia', '3': 'Cytochrome P450 induction'}
# {'0': 'Defect in ATM gene', '1': 'Adenosine deaminase deficiency', '2': 'NADPH oxidase deficiency', '3': 'Defect in BTK gene'}
# {'0': 'They are known as Grignard reactions.', '1': 'The reaction products are 1,5-dicarbonyl compounds.', '2': 'The enolate that participates in this reaction is known as an acceptor.', '3': 'In these reactions γ-ketoesters are obtained.'}
# {'0': 'Intracytoplasmic vacuolations', '1': 'Multinucleated giant cells', '2': 'Belongs to Herpes family', '3': "It's a RNA virus"}
# {'0': 'Covalently X-links DNA', '1': 'Blocks microtubule formation', '2': 'Intercalates between DNA', '3': 'Modifies DNA transcription and protein synthesis'}
# {'0': 'MLH1', '1': 'TP53', '2': 'DCC', '3': 'KRAS'}
# {'0': 'Pulmonary aery stenosis', '1': 'Coarctation of aoa', '2': 'Ankylosis spondylitis', '3': 'Rheumatic fever'}
# {'0': '1/2', '1': '3/4', '2': '1/4', '3': '2/3'}
# {'0': 'Activation of the antithrombin enzyme', '1': 'Inhibition of the cyclooxygenase enzyme', '2': 'Inhibition of vitamin K-dependent clotting factors', '3': 'Blockage of glycoprotein IIb/IIIa receptors'}
# {'0': 'Maxillary aery', '1': 'Stapedial aery', '2': 'Subclan aery', '3': 'Common carotid aery'}
# {'0': '5 years', '1': '10 years', '2': '15 years', '3': '25 years'}
# {'0': 'Solitary mastocytoma', '1': 'Uicaria pigmentosa', '2': 'Telangiectasia macularis eruptiva perstans', '3': 'Diffuse erythrodermic'}
# {'0': 'III cranial pair.', '1': 'Optic chiasma.', '2': 'Upper cervical ganglion.', '3': 'Spinal bulb.'}
# {'0': 'Semiquinone', '1': 'Quinone.', '2': 'Ubiquinol', '3': 'Ubiquinone'}
# {'0': 'It has a plasma membrane and a genome composed of RNA.', '1': 'His serotypes 16 and 18 are associated with cervical cancer.', '2': 'Blood transfusion is one of its main routes of transmission.', '3': 'Its treatment includes inhibitors of viral reverse transcriptase.'}
# {'0': 'Half.', '1': 'The double.', '2': '8 times greater', '3': '16 times greater'}
# {'0': 'arthritis', '1': 'Recurrent thrombosis', '2': 'Red rash', '3': 'Kidney failure'}
# {'0': '2.1', '1': '2.2', '2': '3.1', '3': '3.2'}
# {'0': 'Silica', '1': 'Feldspar', '2': 'Calcium carbonate', '3': 'Amorphous material'}
# {'0': 'Square plane, tetrahedral, octahedral, cubic.', '1': 'Triangular plane, triangular pyramid.', '2': 'Pyramid of square base, triangular pyramid.', '3': 'There are no ionic oxides.'}
# {'0': 'Polysulfide.', '1': 'Polyether.', '2': 'Addition silicon.', '3': 'Condensation Silicon.'}
# {'0': '1', '1': '2', '2': '3', '3': '4'}
# {'0': 'Cognitive-behavioral therapy', '1': 'Intralesional steroids', '2': 'Oral griseofulvin', '3': 'Systemic steroids'}
# {'0': 'Serotonin, norepinephrine, and dopamine', '1': 'Norepinephrine and dopamine', '2': 'Serotonin receptor antagonism', '3': 'Alpha-2 receptor antagonism'}
# {'0': 'Medicine for hospital use.', '1': 'Orphan drug.', '2': 'Homeopathic medicine.', '3': 'Hospice medication.'}
# {'0': 'Exertional heat stroke', '1': 'Malignant hyperthermia', '2': 'Neuroleptic malignant syndrome', '3': 'Thyroid storm'}
# {'0': 'Retinal detachment', '1': 'Retinitis pigmentosa', '2': 'Optic neuritis', '3': 'Subcapsular cataract'}
# {'0': 'Photosensitivity', '1': 'Rhabdomyolysis', '2': 'Ototoxicity', '3': 'QT prolongation'}
# {'0': '67 and 70', '1': '70 and 67', '2': '61 and 69', '3': '69 and 61'}
# {'0': "Nodular lymphocyte predominant Hodgkin's lymphoma", '1': "Lymphocyte rich Hodgkin's lymphoma", '2': 'Diffuse large B-cell lymphoma', '3': 'Small cell lymphoma', 'correct answer': "Lymphocyte rich Hodgkin's lymphoma"}
# {'0': 'Progesterone in corpus luteum', '1': 'Estrogen in adipose tissue', '2': 'Follicle stimulating hormone in the adenohypophysis', '3': 'Dopamine in the hypothalamus'}
# {'0': 'Chromosome', '1': 'Pituitary function tests', '2': 'hCG stimulation test', '3': 'Antimüllerian hormone serum concentrations'}
# {'0': 'It is double-stranded.', '1': "The 2 'carbons are attached to 2 H atoms while in the RNA they are attached to an H atom and an OH group.", '2': 'DNA has T nucleotides instead of U.', '3': 'It forms stable tertiary structures.'}
# {'0': 'Increased HbF and normal HbA2', '1': 'Normal HbF and normal HbA2', '2': 'Normal HbF and decreased HbA2', '3': 'Decreased HbF and normal HbA2'}
# {'0': 'Lipid solvent and membrane denaturant.', '1': 'Alkylator', '2': 'Oxidizer', '3': 'Protein denaturant.'}
# {'0': 'Ibuprofen.', '1': 'Oxycodone', '2': 'Duloxetine', '3': 'Paracetamol.'}
# {'0': 'VLDL', '1': 'LDL', '2': 'HDL', '3': 'Chylomicrons'}
# {'0': 'Regional wall motion abnormality', '1': 'Troponin level', '2': 'Both', '3': 'None'}
# {'0': 'Kwashiorkor', '1': 'Marasmus', '2': 'Beriberi', '3': 'Rickets'}
# {'0': 'Cefepime', '1': 'Gentamicin', '2': 'Levofloxacin', '3': 'Trimethoprim and sulfamethoxazole'}
# {'0': 'Myocardial infarction', '1': 'Tongue infarction', '2': 'Palpable purpura', '3': 'Polyneuropathy'}
# {'0': 'ankylosing spondylitis', '1': 'spinal bone metastasis', '2': 'infectious spondylodiscitis', '3': 'degenerative spinal disease'}
# {'0': 'Lattice type.', '1': 'Meshwork type.', '2': 'Beaded minor connector.', '3': 'None of the above.'}
# {'0': 'Osteoclasts', '1': 'Osteocytes', '2': 'Macrophages', '3': 'None of these'}
# {'0': 'Increased at a rate of acidic drug metabolism in the liver', '1': 'Changing the stability of an acidic drug in the blood', '2': 'Increasing drug free form in the blood, which will help glomerular filtration', '3': 'Reduction of drug recycling in the renal tubules'}
# {'0': 'It refers to each catalytic center.', '1': 'It reflects the average life of the enzyme.', '2': 'It is variable.', '3': 'It is an exponential function.'}
# {'0': '50% of patients is surgical resection good candidate', '1': 'Liver transplantation results up to 5-year survival rate of 80%', '2': 'Preoperative liver function is very important', '3': 'CT arterioportography (CTAP) is an important check, you need to do when checking portal vein cannulation'}
# {'0': 'Differential threshold', '1': 'Absolute threshold.', '2': 'Download threshold.', '3': 'Recognition threshold.'}
# {'0': 'Mycoplasma', '1': 'Chlamydia', '2': 'Streptococcus', '3': 'Legionela'}
# {'0': 'The probability that the next descendant is affected is 25%.', '1': 'The probability that the next descendant is affected is 50%.', '2': 'Having had an affectionate child, the next descendant will also be affectionate.', '3': 'Having had a homozygous F508del son, the next descendant will be a heterozygous carrier (67%) or a homozygous genotype without the mutation (33%).'}
# {'0': 'Glutamate capsule', '1': 'Toxin B', '2': 'IgA protease', '3': 'Sulfatides'}
# {'0': 'The patient does not know which experimental group has been assigned.', '1': 'The investigator does not know which experimental group has been assigned to the patient.', '2': 'Both the patient and the researcher are unaware of which experimental group the patient has been assigned to.', '3': 'No one knows the assignment group.'}
# {'0': 'Vitamin A', '1': 'Folate', '2': 'Vitamin E', '3': 'Vitamin C'}
# {'0': 'Blood in the stool (hematochezia)', '1': 'Change in bowel habits', '2': 'Tenesmus (tenesmus)', '3': 'anemia'}
# {'0': 'Facial defects', '1': 'Cardiac defects', '2': 'Neural tube defects', '3': 'Urogenital defects'}
# {'0': "Student's t", '1': 'Pearson correlation.', '2': 'Spearman correlation.', '3': 'Regression.'}
# {'0': 'Potassium, phosphorus, magnesium', '1': 'Sodium, phosphorus, calcium', '2': 'Potassium, phosphorus, calcium', '3': 'Potassium, sodium, magnesium'}
# {'0': 'Zinc phosphate', '1': 'Polycarboxylate', '2': 'GIC', '3': 'Calcium hydroxide'}
# {'0': 'Deficiency of G6PD', '1': 'Deficiency of xylulose kinase', '2': 'Deficiency of L-gulonolactone oxidase', '3': 'Deficiency of phosphoglucomutase'}
# {'0': 'Suboccipito frontal', '1': 'Mento veical', '2': 'Submentoveical', '3': 'Bitrochanteric'}
# {'0': 'Hepatocellular carcinoma', '1': 'Portal hypertension', '2': 'Spontaneous bacterial peritonitis', '3': 'Hepatorenal syndrome'}
# {'0': '500 ml RL bolus then regulated by indicators', '1': '2000 ml bolus', '2': '1000 ml bolus then regulated by clinical indicators', '3': '250 ml bolus'}
# {'0': 'Epiphysis', '1': 'Metaphysis', '2': 'Diaphysis', '3': 'Physis'}
# {'0': 'Reduplicative paramnesia.', '1': 'Delirio of Sosias.', '2': 'Agnosia of faces.', '3': 'Sham syndrome.'}
# {'0': 'Epidemic in India', '1': 'Spreads by droplet', '2': 'Diagnosed by PCR', '3': 'Casued by SARS CoV'}
# {'0': 'DATSCAN.', '1': 'Nerve conduction study.', '2': 'Electroencephalogram.', '3': 'Copper in 24-hour urine.'}
# {'0': 'Mucormycosis', '1': 'Cryptococcus neoformans', '2': 'Histoplasma capsulatum', '3': 'Rhizopus'}
# {'0': 'Brachycephaly', '1': 'Oxycephaly', '2': 'Trigonocephaly', '3': 'Scaphocephaly'}
# {'0': 'Diuretic overdose', '1': 'Osmotic diuresis', '2': 'Excess production of aldosterone', '3': 'Insufficient production of antidiuretic hormone'}
# {'0': 'S-Adenosylmethionine.', '1': 'Malonil-CoA.', '2': 'Acetyl-CoA.', '3': 'CO2'}
# {'0': "Bohr's effect", '1': "Halden's effect", '2': 'Higher affinity of HbF for 02', '3': 'None of the above'}
# {'0': 'First step.', '1': 'Second step.', '2': 'Third step.', '3': 'Fourth step.'}
# {'0': 'Brittle fracture', '1': 'Ductile fracture', '2': 'Shear fracture', '3': 'All of the above'}
# {'0': 'Forward direction', '1': 'Backward direction', '2': 'No rotation', '3': 'First forward then backward'}
# {'0': 'IPC 304 A', '1': 'IPC 304 B', '2': 'IPC 305 A', '3': 'IPC 305 B'}
# {'0': 'Most of the time it is not possible to do it on an outpatient basis.', '1': 'The duration of treatment should be at least 6 months when performed on an outpatient basis.', '2': 'In no case should psychodynamically oriented therapies be considered in the ambulatory treatment of anorexia nervosa.', '3': 'In people with hospitalized anorexia it is very convenient to use extremely rigid behavior modification programs.'}
# {'0': 'Moraxella axenfeld', '1': 'Staphylococcus aureus', '2': 'Streptococcus pneumonae', '3': 'Pseudomonas aeruginosa'}
# {'0': 'Membranous glomerulitis', '1': 'Segmental glomerulosclerosis', '2': 'IgA nephropathy', '3': 'Diabetic nephropathy'}
# {'0': 'Mixed stones', '1': 'Pure cholesterol stones', '2': 'Pigment stones', '3': 'Calcium bilirubinate'}
# {'0': 'Late mixed dentition', '1': 'Early mixed dentition', '2': 'Late primary dentition', '3': 'Early permanent dentition'}
# {'0': 'Graft vessel vasculitis', '1': 'Fibrinoid necrosis', '2': 'Interstitial fibrosis', '3': 'Viral inclusions\n"'}
# {'0': 'Extensive nuclearpleomorphism', '1': 'High mitoticrate', '2': 'Capsular and vascularinvasion', '3': 'None of these'}
# {'0': 'Sodium amytal', '1': 'Soneryl', '2': 'Oxalic acid', '3': 'Arsenic'}
# {'0': 'The assessment that people make about their own resources to face the stressful event.', '1': 'The analysis that people make about the nature of the stressful event they face.', '2': 'A reassessment that people make when new information about the stressful event appears.', '3': 'The final assessment that people make about the result achieved with the selected coping strategy.'}
# {'0': 'Follicular carcinoma', '1': 'Papillary carcinoma', '2': 'Anaplastic carcinoma', '3': 'Follicular adenoma'}
# {'0': 'Communication between the right and left atria', '1': 'Right ventricular outflow tract obstruction', '2': 'Increase in pulmonary vascular resistance', '3': 'Decrease in pulmonary vascular resistance'}
# {'0': 'All Monozygotic twins', '1': 'Monochorionic twins', '2': 'Dichorionic twins', '3': 'Siamese twins'}
# {'0': 'M1', '1': 'M2', '2': 'M3', '3': 'M4'}
# {'0': 'Systemic or systematic patient.', '1': 'Identified patient.', '2': 'Triangulated patient.', '3': 'Patient or family member.'}
# {'0': '①③', '1': '②④', '2': '①⑤', '3': '④⑤'}
# {'0': 'HIV protease', '1': 'HIV reverse transcriptase', '2': 'HIV integrase', '3': 'HIV entry into the cell'}
# {'0': '28', '1': '26', '2': '32', '3': '25'}
# {'0': 'Oral screen.', '1': 'Bionator.', '2': 'Cribs.', '3': 'Lip bumper.'}
# {'0': 'Alteration of nuclear cytoplasmic ratio', '1': 'Division of nuclei without division of cytoplasm', '2': 'Large, prominent nuclei', '3': 'Loss of polarity and disorientation of cells'}
# {'0': 'Menstrual phase', '1': 'Ovulatory', '2': 'Post ovulatory', '3': 'Pre follicular'}
# {'0': 'Sphenopalatine aery', '1': 'Anterior ethmoidal aery', '2': 'Greater palatine aery', '3': 'Septal branch of superior labial aery'}
# {'0': 'Antegrade', '1': 'Retrograde', '2': 'Antegrade and retrograde', '3': 'None'}
# {'0': 'Topical ciprofloxacin', '1': 'Irrigation of lacrimal cannaliculi', '2': 'Oral amoxicillin-clavulanate therapy', '3': 'CT scan of the orbit\n"'}
# {'0': 'Collecting ducts', '1': 'Ductus deferens', '2': 'Distal convoluted tubule', '3': "Bowman's capsule"}
# {'0': 'Extraction of the offending tooth', '1': 'Root canal treatment if possible', '2': 'No treatment should be given', '3': 'Incision and drainage of abscess'}
# {'0': 'Van den Bergh reaction', '1': "Ehrlich's Reaction", '2': "Schlesinger's Reaction", '3': "Fouchet's Reaction", 'correct answer': "Ehrlich's Reaction"}
# {'0': 'Polysulfide', '1': 'Polyether', '2': 'ZOE', '3': 'Irreversible hydrocolloids'}
# {'0': 'External iliac nodes', '1': 'Internal iliac nodes', '2': 'Pre & Para aortic nodes', '3': 'Superficial inguinal nodes'}
# {'0': 'Repeat the cytology in 1 month.', '1': 'Colposcopy with eventual biopsy.', '2': 'Hysterectomy with bilateral salpinguectomy and preservation of ovaries.', '3': 'Fractional uterine curettage'}
# {'0': 'Mastication', '1': 'Deglutition', '2': 'Facial expression', '3': 'Eye movement'}
# {'0': 'Aspaic acid, glycine, uric acid', '1': 'Aspaate, glycine,', '2': 'Aspaate, glutamate', '3': 'Aspaate, glycine, glutamine'}
# {'0': 'Stress fracture of proximal tibia', '1': 'Medial meniscus tear', '2': 'Medical collateral ligament (MCL) sprain', '3': 'Pes anserine bursitis'}
# {'0': 'Caninus.', '1': 'Triangularis.', '2': 'Zygomaticus major.', '3': 'No muscle attachment.'}
# {'0': 'The charge of the ions to dissociate.', '1': 'The molality of ions.', '2': 'The molarity of ions.', '3': 'The number of ions to dissociate.'}
# {'0': 'Concentration of immunoglobulins (IgG, IgA, IgM) in peripheral blood.', '1': 'Bactericidal activity of phagocytes.', '2': 'Count of circulating T and B lymphocyte populations.', '3': 'Titration of specific anti-pneumococcal antibodies pre- and post-vaccination.'}
# {'0': 'Recruitment', '1': 'Treatment', '2': 'Analysis', '3': 'Observation'}
# {'0': 'Radical vulvectomy with sentinal LN biopsy', '1': 'Wide excision', '2': 'Simple vulvectomy', '3': 'Chemoradiation with resection'}
# {'0': 'Focal segmental glomerulosclerosis', '1': 'Membranous nephropathy', '2': 'Minimal change disease', '3': 'Amyloidosis'}
# {'0': 'Vaginal discharge', '1': 'Dysparenuria', '2': 'Infeility', '3': 'Chronic pelvic pain'}
# {'0': 'Pyruvate is converted into lactate in the liver.', '1': 'Lactate is a source of glucose in the liver.', '2': 'Lactate is converted into pyruvate in skeletal muscle.', '3': 'Pyruvate is a source of glucose in skeletal muscle.'}
# {'0': 'Ankylosing spondylitis', '1': 'Gout', '2': 'Osteoarthritis', '3': 'Fibromyalgia'}
# {'0': 'Expectant management', '1': 'Histopathologic evaluation', '2': 'Elective surgical management', '3': 'Immediate surgical management'}
# {'0': 'USG abdomen', '1': 'Genetic testing', '2': 'Hormonal study', '3': 'All of above'}
# {'0': 'Relaxation techniques (relaxation techniques)', '1': 'Anti-acetylcholine drugs (anticholinergic medication)', '2': 'Urinate every hour during the day', '3': 'Bladder training (bladder training)'}
# {'0': 'It intervenes in glandular growth.', '1': 'Involved in the metabolism of iron.', '2': 'Regulates the renal concentration of water.', '3': 'Involved in the control of extracellular concentrations of calcium and phosphate.'}
# {'0': 'Enamel spindles', '1': 'Dentinoenamel junction', '2': 'Enamel lamellae', '3': 'Striae of Retzius'}
# {'0': 'Temporary amnesia (transient global amnesia)', '1': 'Ezihaimo disease (Alzheimer disease)', '2': 'Amnesia stroke (amnestic stroke)', '3': 'Seizures (epileptic seizures)'}
# {'0': 'Roxatidine', '1': 'Pirenzipine', '2': 'Betaxolol', '3': 'Misoprostol'}
# {'0': 'Damage to respiratory apparatus', '1': 'Damage to respiratory centre', '2': 'Damage to both respiratory apparatus and respiratory centre', '3': 'Massive lung contusion alone'}
# {'0': 'Influenza (influenza)', '1': 'Syphilis (Syphilis)', '2': 'Dengue (Dengue fever)', '3': 'Mycoplasma pneumoniae (Mycoplasma pneumoniae) infection in 17 of the following statements related to pulmonary edema, whichever is correct?'}
# {'0': 'Jobs syndrome', '1': 'Wiscott Aldrich syndrome', '2': 'Chediak-Higashi syndrome', '3': 'Digeorge syndrome'}
# {'0': 'Thyrotropin - releasing hormone', '1': 'Epinephrine', '2': 'LH', '3': 'Cortisol'}
# {'0': 'They are used for the formation of hybrid molecules by recombination.', '1': "They recognize and cut phosphoester bonds starting at the 5 'ends.", '2': 'They recognize and cut DNA in specific sequences.', '3': 'They recognize and cut DNA into nucleosome-free sequences.'}
# {'0': 'Phospholipase A', '1': 'Phospholipase C', '2': 'Guanylate cyclase', '3': 'Protein kinase C'}
# {'0': 'Sulfasalazine', '1': 'Chloroquine', '2': 'Methotrexate', '3': 'Leflunomide'}
# {'0': 'Minimal enlarged apical foramen', '1': 'Shape of the canal can be changed', '2': 'Use of 3-5 times larger than first binding file', '3': 'Original canal curvature should be altered to make it compatible with obturating material'}
# {'0': 'Mifepristone', '1': 'Flutamide', '2': 'Finasteride', '3': 'Metyrapone'}
# {'0': 'For users with a reduced contribution of 10%.', '1': 'For users exempt from contributions.', '2': 'For users with a contribution of 40%.', '3': 'For recipes for medicines and health products that are not financed.'}
# {'0': 'Height for age', '1': 'Weight for age', '2': 'Weight for height', '3': 'Mid-arm circumference'}
# {'0': 'Loss of consciousness.', '1': 'Tonic-clonic seizures.', '2': 'Post-critical phase', '3': 'Duration less than 30 seconds.'}
# {'0': 'Obesity is a risk factor', '1': 'C. albicans is the most common causative species', '2': 'Central scaling', '3': 'Satellite lesions'}
# {'0': 'Free gingival graft.', '1': 'Free connective tissue graft.', '2': 'Laterally displaced graft.', '3': 'Coronally displaced graft.'}
# {'0': 'Cutting efficiency.', '1': 'Cutting effectiveness.', '2': 'Cutting fraction.', '3': 'None.'}
# {'0': 'Absence of progesterone', '1': 'Excess of estrogen', '2': 'Hypothalmic pitutary defect', '3': 'High progesterone'}
# {'0': 'Completed early reperfusion of the infarct-related artery in order to prevent the expansion of the infarct', '1': 'Prevention of death and other complications', '2': 'In preventing coronary occlusion', '3': 'At the same time the treatment of non-infarct-related artery stenosis in order to avoid the remnants of hypoxia'}
# {'0': '(Paco)', '1': 'Hemoglobin oxygen saturation (hemoglobin saturation; Sa .2) changes little', '2': 'Total amount of oxygen in the blood (total oxygen content) increased significantly', '3': 'Presented respiratory alkalosis (respiratory alkalosis)'}
# {'0': 'Jones fracture', '1': 'Shin splint', '2': 'Lisfranc fracture', '3': 'Nutcracker'}
# {'0': 'Iritis', '1': 'Cataract', '2': 'Conjunctivitis', '3': 'Retinal damage'}
# {'0': 'Royal Legislative Decree 1/2015, of July 24, Consolidated text of the Law on Guarantee and rational use of medicines and health products.', '1': 'Royal Decree 1015/2009, of June 19, which regulates the availability of medicines in special situations.', '2': 'Royal Decree 782/2013, of 11 October, on the distribution of medicines for human use.', '3': 'Royal Decree 824/2010, of June 25, which regulates pharmaceutical laboratories, manufacturers of active pharmaceutical ingredients and foreign trade in medicines and medicines under investigation.'}
# {'0': '①①①', '1': 'Only ①①', '2': '①①', '3': 'Only ①'}
# {'0': 'Intraorbital margin', '1': 'Fronto-zygomatic suture region', '2': 'Zygomatico-maxillary buttress region', '3': 'Symmetry of arch'}
# {'0': 'Losartan', '1': 'Spironolactone', '2': 'Hydrochlorothiazide', '3': 'Amlodipine'}
# {'0': 'Anti-double stranded (Ds) DNA', '1': 'HLA-B51', '2': 'ANCA', '3': 'HLA-B27'}
# {'0': 'Multicentric', '1': 'Non-functional', '2': 'Anatomically benign', '3': 'Clinically persistent'}
# {'0': 'Carcinoma glottic', '1': 'Carcinoma subglottic', '2': 'Carcinoma nasopharynx', '3': 'Carcinoma supraglottic'}
# {'0': 'Smooth broaches.', '1': 'Barbed broaches.', '2': 'Reamers.', '3': 'Files.'}
# {'0': 'Pneumoperitoneum', '1': 'Subphrenic abscess', '2': 'Pneumomediastinum', '3': 'Amebic liver abscess'}
# {'0': 'Slippage in lingual pouch', '1': '# of ramus of mandible', '2': 'Excessive Haemorrhage', '3': 'Dry socket'}
# {'0': 'Epithelial.', '1': 'Conjunctive.', '2': 'Muscular.', '3': 'Nervous.'}
# {'0': 'B lymphocytes', '1': 'Macrophage (Macrophage)', '2': 'Kill T lymphocytes (Cytotoxic T cell)', '3': 'Dendritic cells (Dendritic cell)'}
# {'0': 'Sodium', '1': 'Potassium', '2': 'Glucose', '3': 'Ascorbate'}
# {'0': 'Measles', '1': 'Urushiol-induced dermatitis', '2': 'Chickenpox', '3': 'Rubella'}
# {'0': "Bruton's agammaglobulinemia", '1': 'IgA deficiency', '2': 'Hyper-IgM syndrome', '3': 'Hyper-IgD syndrome', 'correct answer': "Bruton's agammaglobulinemia"}
# {'0': 'Milk alkali syndrome', '1': 'Nephrolithiasis', '2': 'Paradoxical aciduria', '3': 'Secondary amylodosis'}
# {'0': '280 - 300', '1': '250 - 270', '2': '300 - 320', '3': '210 - 230'}
# {'0': 'Chronic insufficiency of adrenal cortex', '1': 'Chronic insufficiency of adrenal medulla', '2': 'Insufficiency of pancreas', '3': 'Hypofunction of thyroid gland'}
# {'0': 'Cefoperazone', '1': 'Cefaclor', '2': 'Ceftriaxone', '3': 'Cefotaxime'}
# {'0': 'Interruption of breastfeeding.', '1': 'Risk of alternation of the maternal / fetal dyad.', '2': 'Ineffective breastfeeding.', '3': 'Ineffective maternity process risk.'}
# {'0': 'Campylobacter spp.', '1': 'Staphylococcus aureus.', '2': 'Clostridium difficile.', '3': 'Yersinia enterocolitica.'}
# {'0': 'Neuro degenerative diseases', '1': 'Auto immune disorders', '2': 'Myocardial infarction', '3': 'Stroke'}
# {'0': 'Can be transmitted on medical equipment even after autoclaving instruments', '1': 'Contains genetic material but is unable to survive independent from a host', '2': 'Has a cell wall containing peptidoglycan', '3': 'Leads to intracellular aggregations of hyperphosphorylated tau protein'}
# {'0': 'Is a fungal infection', '1': '311 nm narrow band ultraviolet B light is an effective treatment', '2': 'No isomorphic phenomenon (isomorphic phenomenon)', '3': 'Oral steroids are the best disposal'}
# {'0': 'Children', '1': 'Adolescent', '2': 'Geriatrics', '3': 'None of the above'}
# {'0': 'Knee medial ligament', '1': 'Lateral ligaments of the knee', '2': 'Anterior cruciate ligament', '3': 'After the posterior cruciate ligament'}
# {'0': 'Hepatic gluconeogenesis is activated.', '1': 'Ketone bodies become the main source of energy for the liver.', '2': 'The beta-oxidation of fatty acids in the muscle is inhibited.', '3': 'In muscle increases the activity of pyruvate dehydrogenase (PDH) and glucose synthesis.'}
# {'0': 'Common interosseus aery', '1': 'Radial aery', '2': 'Median aery', '3': 'Brachial aery'}
# {'0': 'Bruxism.', '1': 'Thumb sucking.', '2': 'Mouth breathing.', '3': 'Tongue thrusting.'}
# {'0': 'Are penicillinase resistant', '1': 'Produce acid during metabolism', '2': 'Produce extracellular polysachharides', '3': 'Ferment carbohydrates'}
# {'0': 'Sporotrichosis', '1': 'Basal cell carcinoma', '2': 'Actinic keratosis', '3': 'Seborrheic keratosis\n"'}
# {'0': 'DIC', '1': 'Fac. VIII def.', '2': 'Liver disease', '3': 'Vitamin K deficiency'}
# {'0': 'Cervical intraepithelial Neoplasia', '1': 'Ductal carcinoma in situ of breast', '2': 'Lobular Carcinoma in situ of breast', '3': 'Vaginal intraepithelial Neoplasia'}
# {'0': 'Ineffective confrontation of the community.', '1': "Ineffective management of the community's therapeutic regimen.", '2': 'Provision to improve community coping.', '3': 'Ineffective denial of the community.', 'correct answer': "Ineffective management of the community's therapeutic regimen."}
# {'0': 'Delusional disorder', '1': 'Mood disorder with psychotic features', '2': 'Schizoid personality disorder', '3': 'Schizophrenia'}
# {'0': 'Effacement of podocyte foot processes', '1': 'Subepithelial ‘spike and dome’ deposits', '2': 'Subepithelial humps', '3': 'Subendothelial thickening'}
# {'0': 'Single-stranded DNA (+).', '1': 'Single-stranded DNA (-).', '2': 'Single chain RNA (+).', '3': 'Single chain RNA (-).'}
# {'0': 'Lymphatic obstruction', '1': 'Endothelial cell contraction', '2': 'Small arteries', '3': 'Platelet adhesion inhibiting effect'}
# {'0': 'Often <aggregation occurs at a temperature at 37 ℃', '1': 'Mycoplasma pneumoniae is possible pathogens', '2': 'Its antibody IgG', '3': 'Steroid treatment ineffective'}
# {'0': 'BOAA', '1': 'Aflatoxin', '2': 'Sanguinarine', '3': 'Pyrrozolidine'}
# {'0': 'Type III', '1': 'Type IV', '2': 'Type V', '3': 'Type VI'}
# {'0': 'Long junctional epithelium', '1': 'Collagen adhesion', '2': 'Scar tissue attachment', '3': 'Connective tissue attachment'}
# {'0': 'Quilomicrons.', '1': 'VLDL.', '2': 'LDL.', '3': 'HDL.'}
# {'0': 'They inhibit the manifestation of negative emotions.', '1': 'They passively accept the diagnosis.', '2': 'They learn to express their negative emotions.', '3': 'They present characteristics of independent and responsible personality.'}
# {'0': 'Ms. Zhu should undergo regular screening for liver cancer, including abdominal ultrasound and alpha-fetoprotein', '1': 'Ms. Zhu acceptable antiviral therapy', '2': 'The current standard treatment for hepatitis C is a long-acting interferon (pegylated interferon) combined Leibaweilin (ribavirin) and Protease inhibitors (protease inhibitor)', '3': 'If we can clear the hepatitis C virus, can reduce the risk of cirrhosis and liver cancer'}
# {'0': 'Damage to the lacrimal ducts', '1': 'Non-bilious projectile vomiting', '2': 'Possible anaphylaxis and urticaria', '3': 'Sedation and increased sleepiness'}
# {'0': 'Outliers', '1': 'Interquartile range', '2': 'Difference of means', '3': 'Difference of proportions'}
# {'0': 'Lysine, Arginine and Histidine.', '1': 'Lysine, Histidine and Tryptophan.', '2': 'Arginine, Glycine and Proline.', '3': 'Arginine, Lysine and Proline.'}
# {'0': 'B lymphocytes', '1': 'Mast cell', '2': 'T lymphocytes', '3': 'Plasma cells'}
# {'0': 'Shoulder with bevel.', '1': 'Knife edge.', '2': 'Chamfer.', '3': 'None.'}
# {'0': 'Anti-mitochondrial antibodies', '1': 'Perinuclear anti-neutrophil cytoplasmic antibodies', '2': 'Anti-HAV IgM', '3': 'Anti-HEV IgG'}
# {'0': 'HDV co-infection with HBV can be acute (coinfection), or repeated infection (superinfection) in HBV asymptomatic carrier', '1': 'Repeated infection HDV, have a bad effect on the original chronic HBV asymptomatic carrier, could prompt rapid deterioration of liver disease or cause fulminant hepatic failure', '2': 'Lower HDV and HBV co-infection after acute evolve into chronic hepatitis D opportunities', '3': 'interferon (or pegylated interferon) is the only proven effective in the treatment of HDV medicament, a high cure rate (> 80%) and not easy to relapse'}
# {'0': 'Albendazole', '1': 'Mebandazole', '2': 'Praziquintal', '3': 'Pyrantelpamoate'}
# {'0': 'Previous pregnancy with child having neural tube defect', '1': 'Megaloblastic anaemia', '2': 'Hemoglobinopathies', '3': 'All of the above'}
# {'0': '15;17', '1': '14;18', '2': '11;14', '3': '8;14'}
# {'0': 'Myocytes', '1': 'Neutrophils', '2': 'Endothelial cells', '3': 'Smooth muscle cells'}
# {'0': 'Gastroscopy', '1': 'Colonoscopy', '2': 'Laparotomy', '3': 'Percutaneous gallbladder drainage'}
# {'0': 'Perform an incisional biopsy', '1': 'Perform excisional biopsy', '2': 'Scrape for exfoliative cytology', '3': 'Observe for two weeks'}
# {'0': 'Alkaptonuria', '1': 'Albinism', '2': 'Carcinoid', '3': 'Phenylketonuria'}
# {'0': 'Epiosteal implant.', '1': 'Transosteal implant.', '2': 'Endosteal implant.', '3': 'None.'}
# {'0': 'Chest X-ray', '1': 'Tracheo-bronchoscopy', '2': 'CT scan', '3': 'Esophagoscopy'}
# {'0': 'Tidal volume', '1': 'Residual volume', '2': 'Vital capacity', '3': 'None'}
# {'0': 'Moisture free environment', '1': 'Application of pressure', '2': 'Acid etching', '3': 'Continued packing'}
# {'0': 'Alpha rays', '1': 'Beta rays', '2': 'Gamma rays', '3': 'Cathode rays'}
# {'0': 'Fructokinase', '1': 'Aldolase B', '2': 'Gal actokinase', '3': 'Galactose - 1 - phosphate uridyl transferase'}
# {'0': 'Similary.', '1': 'Much larger in the left because the post load is greater.', '2': 'Much smaller in the right because the ejection pressure is lower', '3': 'Much smaller in the right because the musculature of the right ventricle is smaller.'}
# {'0': '2 days after treatment', '1': '1 week after treatment', '2': '2 weeks after treatment', '3': '3 weeks after treatment'}
# {'0': 'Primary intention.', '1': 'Secondary intention.', '2': 'Delayed healing.', '3': 'Tertiary intention.'}
# {'0': 'Determine the differentiation of the male sex.', '1': 'It is inhibited by the Müller inhibitory substance.', '2': 'It is stimulated by testosterone.', '3': "It is parallel to the regression of Wolff's ducts."}
# {'0': 'RNA-replicase.', '1': 'DNA-dependent RNA polymerase.', '2': 'RNA-dependent DNA polymerase.', '3': 'DNA-dependent DNA polymerase.'}
# {'0': 'Shigella dysenteriae', '1': 'Staphylococcus aureus', '2': 'Enterotoxigenic Escherichia coli', '3': 'Bacillus cereus'}
# {'0': '14 weeks', '1': '18 weeks', '2': '22 weeks', '3': '26 weeks'}
# {'0': 'Focal nodular hyperplasia', '1': 'Chronic regenerative hyperplasia', '2': 'Hepatoblastoma', '3': 'None'}
# {'0': 'Graves disease', '1': "Hashimoto's thyroiditis", '2': 'Follicular carcinoma', '3': 'Medullary carcinoma thyroid'}
# {'0': 'Mantle dentin', '1': 'Secondary dentin', '2': 'Reactionary dentin', '3': 'Indeed dermal tubules'}
# {'0': 'Epitope', '1': 'Paratope', '2': 'Both epitope and paratope', '3': 'None of the above'}
# {'0': 'Sinus Rx', '1': 'Thoracic CT.', '2': 'Methacholine test.', '3': 'Prick-test'}
# {'0': 'V', '1': 'Al', '2': 'Ti', '3': 'Al, V'}
# {'0': 'Cease for about 30 minutes', '1': 'Remain the same', '2': 'Increase markedly', '3': 'Decrease slightly'}
# {'0': 'Self-treatment is the most common response to illness situations.', '1': 'Self-treatment includes preventive measures and the management of chronic situations.', '2': 'It consists of health and illness behaviors.', '3': 'It does not imply consulting professionals and using their services.'}
# {'0': 'Autosomal dominant', '1': 'Autosomal recessive', '2': 'Multifactorial', '3': 'X-linked dominant'}
# {'0': 'Quilomicrons.', '1': 'High density lipoproteins (HDL).', '2': 'Low density lipoproteins (LDL).', '3': 'Very low density lipoproteins (VLDL).'}
# {'0': 'Partition chromatography.', '1': 'Ion chromatography.', '2': 'Chromatography of exclusion by sizes.', '3': 'Affinity chromatography.'}
# {'0': 'Benzoic amino acid (procaine).', '1': 'Benzothiazepines (diltiazem).', '2': '5-substituted triptamines (sumatriptam).', '3': 'Sulfonylureas (tolbutamide).'}
# {'0': '1', '1': '2', '2': '3', '3': '4'}
# {'0': 'Vitiligo', '1': 'Tinea versicolor', '2': 'Pityriasis alba', '3': 'Halo nevus'}
# {'0': 'High-pitched emotions', '1': 'Energetic', '2': 'Ideas leap', '3': 'Evil delusion'}
# {'0': 'Insulin, potassium, IV fluids, and glucose', '1': 'IV fluids only', '2': 'Oral rehydration', '3': 'Supportive therapy and close monitoring'}
# {'0': 'Lichen planus', '1': 'Erythema multiforme', '2': 'Pemphigus', '3': 'Leukoplakia'}
# {'0': 'Zinc phosphate', '1': 'GIC', '2': 'Zinc oxide eugenol', '3': 'Silicate'}
# {'0': 'Trigeminal nerve', '1': 'Facial nerve', '2': 'Glossopharyngeal nerve', '3': 'Hypoglossal nerve'}
# {'0': 'Optic canal', '1': 'Intra ocular pa', '2': 'Intracranial pa', '3': 'Optic tract'}
# {'0': '2nd molar>1st molar>canine', '1': '1st molar>2st molar>canine', '2': 'Canine>1st molar>2nd molar', '3': 'Canine>2nd molar>1st molar'}
# {'0': 'Both the statements are true', '1': 'Both the statements are false', '2': 'The first statement is true and the second is false', '3': 'The first statement is false and the second is true'}
# {'0': "Ebstein's anomaly", '1': 'Pulmonary atresia', '2': 'Transposition of great arteries', '3': 'Tetralogy of fallot'}
# {'0': 'Anterior cerebral artery infarction stroke (stroke)', '1': 'Carbon monoxide poisoning encephalopathy (encephalopathy)', '2': 'Meningitis (meningoencephalitis)', '3': 'Falx meningioma (falx meningioma)'}
# {'0': 'Low TSH with more t3 or t4', '1': 'High TSH with normal t3 or t4', '2': 'High TSH with euthyroid', '3': 'Increased uptake of t3, but decrease t4'}
# {'0': 'Exhibit internal root resorption', '1': 'Remain vital and functional', '2': 'Be ankylosed', '3': 'Exhibit external root resorption and exfoliate'}
# {'0': 'Wait and watch', '1': 'Extraction and orthodontic treatment', '2': 'Serial extraction', '3': 'Immediate intervention with removal appliance'}
# {'0': 'Administration of botulism antitoxin', '1': 'Surgical fusion of C1/C2', '2': 'Administration of methylprednisolone', '3': 'Administration of pyridostigmine\n"'}
# {'0': '150 Rs', '1': '250 Rs', '2': '500 Rs', '3': '1000 Rs'}
# {'0': 'Theory of self-efficacy of Bandura (1986).', '1': 'Theory of the reasoned action of Ajzen and Fishbein (1980).', '2': 'Health belief model by Becker and Rosenstock (1984).', '3': 'Theory of equilibrium by Herder (1958).'}
# {'0': '-118degC', '1': '-88degC', '2': '-26degC', '3': '-36.5degC'}
# {'0': 'Degranulation of presensitized mast cells', '1': 'Formation of drug-induced autoantibodies', '2': 'Accumulation of porphobilinogen', '3': 'Cell injury due to drug metabolites'}
# {'0': 'Cementum breakdown', '1': 'Cementicles', '2': 'Cementoid', '3': 'Cemental tears'}
# {'0': 'Optic Tract', '1': 'Optic Chiasma', '2': 'Temporal lobe', '3': 'Occipital lobe'}
# {'0': 'Re-evaluate this patient for borderline personality disorder', '1': 'Ask closed-ended questions and use a chaperone for future visits', '2': 'Immediately tell this patient that you can not continue to treat him and avoid any further communication', '3': 'Increase the dosage of this patient’s SSRI'}
# ...
# {'0': 'Petechial rash', '1': 'Ascending paralysis', '2': 'History of exposure to rabbit hides', '3': 'Rice water stools'}
# {'0': 'Bulk product.', '1': 'Intermediate product.', '2': 'Finished product.', '3': 'Packaged product'}
# {'0': 'Regulates plasma osmolarity.', '1': 'Synthesize oxytocin.', '2': 'Receives afferences from retinal ganglion neurons.', '3': 'Mediates the pupillary reflex.'}
# {'0': 'A', '1': 'B', '2': 'C', '3': 'D'}
# {'0': 'autosomal dominant condition', '1': 'amelanotic skin associated with a white forelock', '2': 'Islands of normal or hypermelanotic skin', '3': 'Usually improves with age'}
# {'0': '100 microns', '1': '65nm', '2': '100 nm', '3': '65 microns'}
# {'0': 'Hemolytic anemia with reticulocytosis', '1': 'Photosensitivity', '2': 'Vasculitis', '3': 'Antinuclear antibody（ANA）elevation'}
# {'0': 'They present beliefs related to incompetence or personal disqualification.', '1': 'They consider that they have to get what they want.', '2': 'They consider that their welfare is threatened.', '3': 'They do not tolerate and they seem terrible the unpleasant situations of the life.'}
# {'0': 'Large tongue', '1': 'Micrognathia', '2': 'Hypoglycemia', '3': 'Crowded teeth'}
# {'0': 'Atrophy of G cells', '1': 'Anti-intrinsic factor antibodies', '2': 'Decreased methylmalonic acid levels', '3': 'Antithrombotic state'}
# {'0': 'Endoscopic injection of dextranomer in the intramural ureteral tract.', '1': 'Ureteral reimplantation by open route.', '2': 'Laparoscopic ureteral reimplantation.', '3': 'Conservative treatment by observation and antibiotic / antiseptic prophylaxis.'}
# {'0': 'Middle meningeal artery has tortuous course', '1': 'LA reaches the eyelid via infraorbital foramen', '2': 'Reaction is due to preservative in the L.A., it will subside in some time', '3': 'Pain will subside in few minutes'}
# {'0': 'Patient having history of snoring', '1': 'Patient having beard', '2': 'Old age patient', '3': 'Full set of teeth present'}
# {'0': 'Activation of vascular smooth muscle arterioles beta1-adrenergic-type receptors (β1 adrenergic receptors)', '1': 'Open calcium channels (calcium channel) on arteriolar smooth muscle cells', '2': 'Arterioles increased nitric oxide (NO),', '3': 'Angiotensin converting enzyme activated (angiotensin-converting enzyme)'}
# {'0': 'Petrosal sinus (superior petrosal sinus)', '1': 'Transverse sinus (transverse sinus)', '2': 'Straight sinus (straight sinus)', '3': 'Superior sagittal sinus (superior sagittal sinus)'}
# {'0': 'Acetylcholine (acetylcholine)', '1': 'Adrenaline (epinephrine)', '2': 'Dopamine (dopamine)', '3': 'Serotonin (serotonin)'}
# {'0': 'Only one related factor is allowed per diagnosis.', '1': 'There are a maximum of three related factors.', '2': 'As many as they have associated with the detected problem.', '3': 'All the related ones that can be eliminated or diminished by nursing.'}
# {'0': 'It has increased tensile and compressive strength', '1': 'It has poor tarnish and corrosion resistance', '2': "Its' edge strength is greater", '3': 'Mercury content in the final restoration is less', 'correct answer': "Its' edge strength is greater"}
# {'0': 'Spontaneous fracture of the mandible', '1': 'Pericoronal infection', '2': 'Mumps', '3': "Sjogren's syndrome"}
# {'0': 'Unipolar', '1': 'Bipolar', '2': 'Pseudounipolar', '3': 'Multipolar'}
# {'0': 'Mandibular central incisor', '1': 'Mandibular lateral incisor', '2': 'Maxillary lateral incisor', '3': 'Maxillary 1st premolar'}
# {'0': 'Measles virus (Measles)', '1': 'Respiratory syncytial virus (Respiratory syncytial virus)', '2': 'Human herpes virus type VI (Human Herpesviruses 6)', '3': 'Rotavirus (Rotavirus)'}
# {'0': 'Marginal gingiva into the supporting periodontal tissues', '1': 'Attached gingiva into the supporting periodontal tissues', '2': 'Interdental gingiva into the supporting periodontal tissues', '3': 'All of the above'}
# {'0': '0-6 Hrs', '1': '6-12 Hrs', '2': '12-72 Hrs', '3': '72-96 Hrs'}
# {'0': 'Iron', '1': 'Vitamin E', '2': 'Folic acid', '3': 'Pyridoxine'}
# {'0': '2-3 mm', '1': '3-3.65 mm', '2': '4-4.5 mm', '3': '4-5 mm'}
# {'0': 'Mixed acid', '1': 'Alcoholic', '2': 'Homolactic', '3': 'Heteroláctica.'}
# {'0': 'Memory loss (amnesia)', '1': 'Delirium (delirium)', '2': 'Dementia (dementia)', '3': 'Depression (depression)'}
# {'0': 'Primary Syphilis', '1': 'Secondary syphilis', '2': 'Teiary syphilis', '3': 'Lupus Vulgaris'}
# {'0': 'Upper 1st molar', '1': 'Lower 1st molar', '2': 'Upper 2nd molar', '3': 'Lower 2nd molar'}
# {'0': 'The first stage (stage I)', '1': 'The second phase (stage II)', '2': 'The third stage (stage III)', '3': 'Phase IV (stage IV)'}
# {'0': 'TMPRSS2-ERG or TMPRSS2-ETV1 fusion gene (gene fusions)', '1': 'Chromosome 8q24 deletions (deletion)', '2': 'PTEN gene deletion (deletion)', '3': 'TP53 gene deletion (Deletion) or mutant (mutation)'}
# {'0': 'Lingually and inferiorly in the anterior region and buccally in posterior region.', '1': 'Lingually and inferiorly all over the ridge.', '2': 'Upwards and inwards.', '3': 'Buccally and inferiorly.'}
# {'0': 'Arranged to form the wall lining the brain cells', '1': 'Winding the axons of nerve cells to myelinating', '2': 'Help maintain the proper extracellular fluid potassium ion concentration', '3': 'Action potential'}
# {'0': 'All chemical burns should be removed immediately flush the affected area and a large number of clothing', '1': 'If serious chemical burns caused by acidic pH in the blood and abnormal breathing difficult and may require intubation and mechanical ventilation (Ventilator) to assist breathing endotracheal', '2': 'Hydrofluoric acid (hydrofluoric acid) treatment of burns immediately local lesion of 2.5% calcium gluconate gel (calcium gluconate gel)', '3': 'Cement is an acidic chemical burns burns'}
# {'0': 'Sporotrichosis', '1': 'Chromoblastomycosis', '2': 'Mycetoma', '3': 'Histoplasmosis'}
# {'0': 'Derailment.', '1': 'Tangentiality', '2': 'It speaks adireccional.', '3': 'Alog'}
# {'0': 'SN1.', '1': 'SN2.', '2': 'E1.', '3': 'E2.'}
# {'0': 'Ephedrine', '1': 'Phenylephrine', '2': 'Methoxamine', '3': 'Mephentermine'}
# {'0': 'Merge a joint.', '1': 'Limit range of motion of the joint.', '2': 'Evaluate the extent of the joint injury.', '3': 'Replace the joint and improve its function.'}
# {'0': 'Six.', '1': 'Twelve.', '2': 'Twenty four.', '3': 'Thirty.'}
# {'0': 'Pigment deposition disease', '1': 'Contact dermatitis', '2': 'Infectious skin diseases', '3': 'Connective tissue disease'}
# {'0': 'BRAC', '1': 'RB', '2': 'MYC', '3': 'p16'}
# {'0': 'Fracture of right condyle', '1': 'Fracture of left condyle', '2': 'Dislocation of left condyle', '3': 'Dislocation of both condyles'}
# {'0': 'It is based on a descriptive system of facial expression developed by Izard.', '1': 'It can only be applied to those facial expressions that have an emotional character.', '2': 'It allows to decompose each facial expression in minimum units of movement.', '3': 'Its usefulness is limited to the recognition of true facial expressions.'}
# {'0': '2-10yrs', '1': '15-20yrs', '2': '25-40 yrs', '3': '> 50yrs'}
# {'0': 'Pallidotomy (pallidotomy) or cautery', '1': 'Thalamus stimulation (thalamic stimulation)', '2': 'Hypothalamic stimulation (subthalamic stimulation)', '3': 'Stimulation cerebral cortex (cortical stimulation)'}
# {'0': 'Rheumatic fever (Rheumatic fever)', '1': 'Multiple myeloma (Multiple myeloma)', '2': 'Ankylosing spondylitis (Ankylosing spondylitis)', '3': 'Systemic sclerosis (Systemic sclerosis)'}
# {'0': 'Hormonal therapy', '1': 'Endometrial sampling', '2': 'Hysterectomy', '3': 'Hysterectomy'}
# {'0': 'Lost of pleasure for most activities.', '1': 'Early awakening (at least two hours earlier than usual).', '2': 'Major psychomotor delay.', '3': 'The mood is worse in the afternoon.'}
# {'0': 'The dose LMWH general decided to follow weight like', '1': 'Generally can check clotting time to do the monitoring, for about about twice the normal value', '2': 'Factor Xa can be monitored, if necessary activity to see whether it is appropriate dose of LMWH', '3': 'LMWH is mainly excreted by the kidneys'}
# {'0': 'Hydroxylation of prolines and lysines in collagen.', '1': 'Incorporation of glycine to collagen.', '2': 'Acetylation of prolines in the tropocollagen.', '3': 'Methylation of lysines in collagen.'}
# {'0': 'High GI bleeding', '1': 'No anti-pyretic effect', '2': 'Similar renal toxicity', '3': 'Thromboembolism decreased'}
# {'0': 'Re-experience situations from the past, avoiding the transfer.', '1': 'Relive a traumatic event again in all its intensity.', '2': 'Re-experience traumatic situations or deficit links and correct them through the transfer.', '3': 'A rational learning of the lived event, without emotional connection.'}
# {'0': 'Diagnosis of sickle cell anemia', '1': 'Recombinant DNA', '2': 'South Point ink method (Southern blot)', '3': 'Diagnosis of pregnancy'}
# {'0': 'Strategy for Health Promotion and Disease Prevention of the National Health System.', '1': 'Strategy for addressing the Chronicity of the National Health System.', '2': 'Patient Safety Strategy of the National Health System.', '3': 'Strategy in Diabetes of the National Health System.'}
# {'0': 'Addition silicone', '1': 'Polysulphide', '2': 'Condensation silicone', '3': 'Alginate'}
# {'0': 'Incisal guidance', '1': 'Incisal break', '2': 'Condylar guidance', '3': 'Hanau’s quint'}
# {'0': 'Type 1 error', '1': 'Type 2 error', '2': 'Type 3 error', '3': 'None of the above'}
# {'0': 'Alprazolam', '1': 'Cognitive behavioral therapy', '2': 'Fluoxetine', '3': 'Psychodynamic psychotherapy'}
# {'0': 'Xray', '1': 'CT angiography', '2': 'MRI', '3': 'PET SCAN'}
# {'0': 'Ascaris', '1': 'Strongyloides', '2': 'Enterobius', '3': 'Ancylostome'}
# {'0': 'Alzheimer dementia', '1': 'Frontotemporal dementia', '2': 'Kluver-Bucy syndrome', '3': 'Vascular dementia'}
# {'0': 'Inhaled steroid', '1': 'Transdermal patch', '2': 'Sublingual NTG', '3': 'Rectal diazepam'}
# {'0': 'Less readily', '1': 'More readily', '2': 'Same', '3': 'Undermining resorption'}
# {'0': 'Celomic metaplasia', '1': 'Hematogenous spread', '2': 'Lymphatic spread', '3': 'Retrograde menstruation'}
# {'0': 'Bone resorption factor.', '1': 'Pressure.', '2': 'Anatomic factor.', '3': 'All of the above.'}
# {'0': 'Egypt Haemophilus (Haemophilus aegyptius)', '1': 'Li Rickettsia (Rickettsia rickettsii)', '2': 'Human Mycoplasma (Mycoplasma hominis)', '3': 'Chlamydia trachomatis (Chlamydia trachomatis)'}
# {'0': 'SR', '1': 'MR', '2': 'SO', '3': 'IO'}
# {'0': 'Hydroxylations.', '1': 'Carboxylations', '2': 'Dehydration', '3': 'Desaminations.'}
# {'0': 'Prevent excess posterior translation of the tibia relative to the femur', '1': 'Prevent excess anterior translation of the tibia relative to the femur', '2': 'Resist excess valgus force on the knee', '3': 'Provide a cushion between the lateral tibial and femoral condyles'}
# {'0': 'PAS', '1': 'Sudan black', '2': 'Tyrosine', '3': 'S-100'}
# {'0': 'Bethanechol administration', '1': 'Bladder scan', '2': 'Intravenous fluids', '3': 'Urodynamic studies'}
# {'0': '50 mg/dl', '1': '45 mg/dl', '2': '40 mg/dl', '3': '55 mg/dl'}
# {'0': 'Alanine', '1': 'Adenosine monophosphate', '2': 'Fructose 1,6-bisphosphate', '3': 'Fructose 2,6-bisphosphate'}
# {'0': 'Aortic gap (aortic opening)', '1': 'Esophageal cleft (esophageal opening)', '2': 'Vena cava gap (caval opening)', '3': 'Azygos gap (azygal opening)'}
# {'0': 'Induces the formation of thymidine dimers', '1': 'Induces the formation of disulfide bonds', '2': 'Induces deamination of cytosine', '3': 'Induces breaks in double-stranded DNA'}
# {'0': 'Pin & Tube', '1': 'Edgewise', '2': 'E - Arch', '3': 'Ribbon arch'}
# {'0': 'Zone 1', '1': 'Zone 2', '2': 'Zone 3', '3': 'Zone 4'}
# {'0': 'Adenocarcinoma', '1': 'Pleomorphic carcinoma', '2': 'Small cell carcinoma', '3': 'Squamous cell carcinoma'}
# {'0': 'Pyrazinamide', '1': 'Chloroquine', '2': 'Ethambutol', '3': 'Tetracycile'}
# {'0': 'Scleroderma of the skin lesions and systemic sclerosis (systemic sclerosis) clearly distinguishable skin lesions', '1': 'Rare affect internal organs, the prognosis is good', '2': "Often have Raynaud's phenomenon (Raynaud phenomenon)", '3': 'Linear scleroderma (linear morphea) made good in the limbs of children'}
# {'0': 'Repairing of cementum.', '1': 'Resorption.', '2': 'Functional adaptation.', '3': 'All of the above.'}
# {'0': 'Proceed to a hospital admission resorting to an involuntary commitment if the patient refuses to enter.', '1': 'Try to reassure the patient verbally and with drugs that reduce agitation.', '2': 'Try to convince the patient that he must enter and if he refuses to discharge and recommend going to his mental health center.', '3': 'Inform the family of the need for a hospitalization to be able to treat the patient, since they will refuse to take medication voluntarily for lack of awareness of disease.'}
# {'0': 'Gouty arthritis', '1': 'Rheumatoid arthritis', '2': 'Osteoarthritis', '3': 'Psoriatic arthropathy'}
# {'0': 'Both veex', '1': 'Both breech', '2': 'Both transverse', '3': 'First veex and 2nd transverse'}
# {'0': 'Thromboxane A2', '1': 'Prostaglandin E2', '2': 'Histamine', '3': 'Serotonin'}
# {'0': 'Diabetes', '1': "Wilson's disease", '2': 'Atopic dermatitis', '3': 'Chalcosis', 'correct answer': "Wilson's disease"}
# {'0': '1,2 true & 3,4 false', '1': '2,3 True & 1,4 false', '2': '1,2,3 true & 4 false', '3': 'All are true'}
# {'0': 'Clonidine', '1': 'ACE inhibitors / Enalapril', '2': 'α − Methyldopa', '3': 'Amlodipine'}
# {'0': 'Enlarges hemolytic area of Staphylococcus aureus', '1': 'Produces lipooligosaccharide rather than lipopolysaccharide', '2': 'Produces toxin that increases cAMP levels', '3': 'Tumbling motility in broth at 22 degrees'}
# {'0': 'Newtonian body', '1': 'Bingham body', '2': 'Dilatant', '3': 'Pseudoplastic'}
# {'0': 'Altered sense of smell', '1': 'Intolerance to cold temperatures', '2': 'Thickening of the skin', '3': 'Craving for non-nutritive substances'}
# {'0': 'Motile, flagellated protozoans', '1': 'Long, branching filamentous structures', '2': 'Epithelial cells with stippling', '3': 'Large mucoid capsules'}
# {'0': 'Four hours postprandial hyperglycemia can lead to a phenomenon', '1': 'Postprandial prone to weakness, dizziness and Pirates of the phenomenon', '2': 'Postprandial rise in blood pressure phenomenon prone', '3': 'Sweets postprandial discomfort can be avoided'}
# {'0': 'Case-control study', '1': 'Coho study', '2': 'Cross-sectional study', '3': 'Ecological study'}
# {'0': 'Congenital hea defect', '1': 'Congenital abnormalities', '2': 'Wounds and injuries', '3': 'None of the above'}
# {'0': 'Epidemics', '1': 'Seasonal trends', '2': 'Cyclical trends', '3': 'Secular trends'}
# {'0': 'Atropine', '1': 'EDTA', '2': 'Neostigmine', '3': 'Belladonna'}
# {'0': 'They suppose a form of control of the antecedents of the conduct.', '1': 'They include the reinforcement of omission.', '2': 'They involve isolating the child in a corner of the room.', '3': 'They consist in reducing the aversive stimulation.'}
# {'0': 'red', '1': 'green', '2': 'Deep Purple', '3': 'yellow'}
# {'0': 'Liver and GIT', '1': 'Liver', '2': 'GIT', '3': 'None of the above'}
# {'0': '100', '1': '250', '2': '500', '3': '1000'}
# {'0': '<750 ml', '1': '750 - 1500 ml', '2': '1500 - 2000 ml', '3': '>2000 ml'}
# {'0': 'Lamina propria', '1': 'Submucosa', '2': 'Muscularis', '3': 'Serosa'}
# {'0': 'Ibuprofen oral', '1': 'Oral sucrose', '2': 'Intravenous paracetamol.', '3': 'Intravenous fentanyl.'}
# {'0': '\ue000 and \ue001', '1': '\ue001 and \ue002', '2': '\ue002 and \ue003', '3': '\ue000 and \ue003'}
# {'0': 'Define the objectives.', '1': 'Justify the problem.', '2': 'Establish the reference population.', '3': 'Define the hypothesis.'}
# {'0': 'It is an individual treatment.', '1': 'The use of different formats: individual, group and telephone consultations.', '2': 'Its exclusively group format.', '3': 'His emphasis on transfer.'}
# {'0': 'By the cells of ectodermal and mesodermal composition', '1': 'Original Article (primitive streak) caused by insufficiency', '2': 'Prenatal ultrasound examination is not easy to find', '3': 'Often occurs in newborn boys'}

# %%
df_gen.to_csv("path_to_save_generic_question.csv")
df_causal.to_csv("path_to_save_causal_question.csv")
